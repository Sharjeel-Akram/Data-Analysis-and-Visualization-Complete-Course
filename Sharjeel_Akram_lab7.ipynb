# %% [markdown]
# # **Car Dekho Dataset**

# %%
# Dataset link
# https://raw.githubusercontent.com/akmalatnamal/davlab7/main/car_dekho_full.csv

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('https://raw.githubusercontent.com/akmalatnamal/davlab7/main/car_dekho_full.csv')
df.head()
# Out:
#    Year  Current_Selling_Price    MRP  Kms_Driven
# 0  2016                   5.25   5.70        3493
# 1  2005                   3.51  13.70       75000
# 2  2010                   0.31   1.05      213000
# 3  2006                   2.10   7.60       50456
# 4  2005                   0.20   0.57       55000

# %%
sns.jointplot(x = 'Current_Selling_Price', y = 'Year', data= df, kind = 'scatter')

# %%
sns.jointplot(x = 'Current_Selling_Price', y = 'MRP', data= df, kind = 'scatter')

# %%
sns.jointplot(x = 'Current_Selling_Price', y = 'Kms_Driven', data= df, kind = 'scatter')

# %%
x = df['MRP']
y = df['Current_Selling_Price']

# %%
def estimate_coef(x, y):
    n = np.size(x)
    m_x = np.mean(x)
    m_y = np.mean(y)

    SS_xy = np.sum(y*x) - n*m_y*m_x
    SS_xx = np.sum(x*x) - n*m_x*m_x

    b = SS_xy / SS_xx
    a = m_y - b*m_x
 
    return (a, b)
    
b = estimate_coef(x, y)

# %%
def plot_regression_line(x, y, b):
    plt.scatter(x, y, color = "m", marker = "o", s = 30)
    y_pred = b[0] + b[1]*x
    plt.plot(x, y_pred, color = "g")
    plt.xlabel('x')
    plt.ylabel('y')
    plt.show()

plot_regression_line(x, y, b)
